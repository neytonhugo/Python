# %%
import pyautogui
import time
import pyperclip
time.sleep(5)
#ENTRADA DE QUANTIDADES------------------------------------------
time.sleep(4)
pyautogui.PAUSE = 1
pyautogui.hotkey("ctrl","j")#no excel em consumo
pyautogui.press("win")
pyautogui.write("Chrome")
pyautogui.press("enter")
pyautogui.write(r"https://e1lapd.aws.baxter.com/jde/E1Menu.maf")
pyautogui.press("enter")#entrou no jde
time.sleep(3.5)
#HOME menu
pyautogui.hotkey("ctrl","m")
pyautogui.PAUSE = 0.4
#Navegação
pyautogui.press("tab")
#Abre baxter menu principal
pyautogui.press("numlock")
pyautogui.press("down")
#clica em menu principal
for x in range(6):
    x= pyautogui.press("tab")
    
pyautogui.PAUSE = 0.5
pyautogui.press("right")
pyautogui.press("right")#Manufatura
pyautogui.press("right")
pyautogui.press("right")#MFG Brasil
pyautogui.press("right")
pyautogui.press("right")#PDM
pyautogui.PAUSE = 0.1
for x in range(13):
    x= pyautogui.press("tab")#MFG setup

pyautogui.PAUSE = 0.5
pyautogui.press("right")
pyautogui.press("right")
pyautogui.press("right")
time.sleep(3)
pyautogui.press("right")
pyautogui.PAUSE = 0.1
for x in range(15):
    x= pyautogui.press("down")#Entrada consumo
    
pyautogui.press("enter")
time.sleep(3)
pyautogui.hotkey("ctrl","alt","a")
time.sleep(4)
pyautogui.hotkey("ctrl","v")
time.sleep(3)
pyautogui.hotkey("ctrl","alt","o")
time.sleep(3)
pyautogui.hotkey("ctrl","alt","l")
time.sleep(3)
pyautogui.hotkey("ctrl","alt","l")

time.sleep(3)

#PROCESSAMENTO DE QUANTIDADE-------------------------------
pyautogui.PAUSE = 0.7
#HOME menu
pyautogui.hotkey("ctrl","m")
pyautogui.PAUSE = 0.4
#Navegação
pyautogui.press("tab")
#Abre baxter menu principal
pyautogui.press("numlock")
pyautogui.press("down")
#clica em menu principal
for x in range(6):
    x= pyautogui.press("tab")
    
pyautogui.PAUSE = 0.5
pyautogui.press("right")
pyautogui.press("right")#Manufatura
pyautogui.press("right")
pyautogui.press("right")#MFG Brasil
pyautogui.press("right")
pyautogui.press("right")#PDM
pyautogui.PAUSE = 0.1
for x in range(13):
    x= pyautogui.press("tab")#MFG setup

pyautogui.PAUSE = 0.5
pyautogui.press("right")
pyautogui.press("right")
pyautogui.press("right")
time.sleep(3)
pyautogui.press("right")
pyautogui.PAUSE = 0.1
for x in range(17):
    x= pyautogui.press("down")#processar QUANTIDADES
pyautogui.PAUSE = 0.3
pyautogui.press("enter")
time.sleep(3)
pyautogui.press("space")#seleção de dados
for x in range(5):
    x= pyautogui.press("tab")
pyautogui.press("space")#submeter dados enter
time.sleep(3)
for x in range(8):
    x= pyautogui.press("tab")
    
pyautogui.press("l")
pyautogui.PAUSE = 0.7
pyautogui.hotkey("alt","tab")#volta para o excel
pyautogui.PAUSE = 0.2
for x in range(20):
    x= pyautogui.hotkey("ctrl","left")

pyautogui.press("right")
pyautogui.hotkey("ctrl","c")#Pega lote do excel
pyautogui.PAUSE = 0.7
pyautogui.hotkey("alt","tab")
pyautogui.hotkey("ctrl","v")#Cola lote no JDE
pyautogui.hotkey("ctrl","alt","o")
time.sleep(2)
pyautogui.hotkey("ctrl","alt","o")
time.sleep(3)
pyautogui.hotkey("ctrl","alt","o")



#ENTRADA DE HORAS-----------------------------------------------
pyautogui.PAUSE = 0.7
pyautogui.hotkey("alt","tab")
pyautogui.hotkey("ctrl","shift","j")#Excel planilha de horas
pyautogui.hotkey("alt","tab")
pyautogui.PAUSE = 1

#HOME menu
pyautogui.hotkey("ctrl","m")
pyautogui.PAUSE = 0.4
#Navegação
pyautogui.press("tab")
#Abre baxter menu principal
pyautogui.press("numlock")
pyautogui.press("down")
#clica em menu principal
for x in range(6):
    x= pyautogui.press("tab")
    
pyautogui.PAUSE = 0.5
pyautogui.press("right")
pyautogui.press("right")#Manufatura
pyautogui.press("right")
pyautogui.press("right")#MFG Brasil
pyautogui.press("right")
pyautogui.press("right")#PDM
pyautogui.PAUSE = 0.1
for x in range(13):
    x= pyautogui.press("tab")#MFG setup

pyautogui.PAUSE = 0.5
pyautogui.press("right")
pyautogui.press("right")
pyautogui.press("right")
time.sleep(3)
pyautogui.press("right")
pyautogui.PAUSE = 0.1
for x in range(16):
    x= pyautogui.press("down")#Entrada horas
    
pyautogui.press("enter")
time.sleep(3)
pyautogui.hotkey("ctrl","alt","a")
time.sleep(4)
pyautogui.hotkey("ctrl","v")
time.sleep(3)
pyautogui.hotkey("ctrl","alt","o")
time.sleep(3)
pyautogui.hotkey("ctrl","alt","l")
time.sleep(3)
pyautogui.hotkey("ctrl","alt","l")

time.sleep(3)



#PROCESSAMENTO HORAS------------------------
pyautogui.PAUSE = 0.7
#HOME menu
pyautogui.hotkey("ctrl","m")
pyautogui.PAUSE = 0.4
#Navegação
pyautogui.press("tab")
#Abre baxter menu principal
pyautogui.press("numlock")
pyautogui.press("down")
#clica em menu principal
for x in range(6):
    x= pyautogui.press("tab")
    
pyautogui.PAUSE = 0.5
pyautogui.press("right")
pyautogui.press("right")#Manufatura
pyautogui.press("right")
pyautogui.press("right")#MFG Brasil
pyautogui.press("right")
pyautogui.press("right")#PDM
pyautogui.PAUSE = 0.1
for x in range(13):
    x= pyautogui.press("tab")#MFG setup

pyautogui.PAUSE = 0.5
pyautogui.press("right")
pyautogui.press("right")
pyautogui.press("right")
time.sleep(4)
pyautogui.press("right")
pyautogui.PAUSE = 0.1
for x in range(18):
    x= pyautogui.press("down")#processar HORAS
pyautogui.PAUSE = 0.3
pyautogui.press("enter")
time.sleep(3)
pyautogui.press("space")#seleção de dados
for x in range(5):
    x= pyautogui.press("tab")
time.sleep(3)
pyautogui.press("space")#submeter dados enter
time.sleep(3)
for x in range(8):
    x= pyautogui.press("tab")
    
pyautogui.press("l")
time.sleep(2)
pyautogui.PAUSE = 0.7
pyautogui.hotkey("shift","tab")
pyautogui.press("space")
pyautogui.hotkey("alt","tab")
pyautogui.hotkey("ctrl","shift","h")
pyautogui.hotkey("alt","tab")

pyautogui.click(705, 375,button="right")#Abre complemento
for x in range(5):
    x= pyautogui.press("up")
    
pyautogui.press("enter")#seleciona complemento
    
pyautogui.click(752, 455)
pyautogui.hotkey("ctrl","v")
pyautogui.click(745, 582)#Add valores
time.sleep(30)
pyautogui.hotkey("ctrl","alt","o")
time.sleep(2)
pyautogui.hotkey("ctrl","alt","o")
time.sleep(4)
pyautogui.hotkey("ctrl","alt","o")
pyautogui.press("numlock")

# %%
time.sleep(4)
pyautogui.position()
# Out:
# Point(x=745, y=582)
